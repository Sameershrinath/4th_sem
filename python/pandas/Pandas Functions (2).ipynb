# %% [markdown]
# # Pandas Functions

# %%
import pandas as pd
import numpy as np

# %%
1. df['col_name'].unique()
2. df['col_name'].nunique()
3. df['col_name'].value_counts()
4. pd.crosstab(col1, col2)
5. df.replace({'Key': value})
6. df['col_name'].astype(datatype)

# %%
df = pd.read_excel('Emp_Records.xlsx')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.describe()
# Out:
#              Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count     100.00000  100.000000     100.000000      100.000000     100.000000
# mean   547652.10000   39.238700      58.080000        8.978400  119738.090000
# std    257664.16679   12.066252      12.294106        8.657358   46185.278194
# min    134841.00000   21.100000      40.000000        0.020000   42005.000000
# 25%    328643.75000   28.177500      50.000000        2.152500   83979.750000
# 50%    497414.00000   37.595000      56.000000        6.435000  118049.500000
# 75%    766040.00000   49.900000      61.250000       13.762500  162509.250000
# max    979607.00000   59.470000      90.000000       34.520000  197537.000000

# %%
df.describe(exclude = ['object']) # By default
# Out:
#              Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count     100.00000  100.000000     100.000000      100.000000     100.000000
# mean   547652.10000   39.238700      58.080000        8.978400  119738.090000
# std    257664.16679   12.066252      12.294106        8.657358   46185.278194
# min    134841.00000   21.100000      40.000000        0.020000   42005.000000
# 25%    328643.75000   28.177500      50.000000        2.152500   83979.750000
# 50%    497414.00000   37.595000      56.000000        6.435000  118049.500000
# 75%    766040.00000   49.900000      61.250000       13.762500  162509.250000
# max    979607.00000   59.470000      90.000000       34.520000  197537.000000

# %%
df.describe(include = ['object'])
# Out:
#        First Name    City
# count         100     100
# unique         79     100
# top         Nancy  Denver
# freq            4       1

# %%
df.describe(include = 'all')
# Out:
#               Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  \
# count      100.00000        100  100.000000     100.000000      100.000000
# unique           NaN         79         NaN            NaN             NaN
# top              NaN      Nancy         NaN            NaN             NaN
# freq             NaN          4         NaN            NaN             NaN
# mean    547652.10000        NaN   39.238700      58.080000        8.978400
# std     257664.16679        NaN   12.066252      12.294106        8.657358
# min     134841.00000        NaN   21.100000      40.000000        0.020000
# 25%     328643.75000        NaN   28.177500      50.000000        2.152500
# 50%     497414.00000        NaN   37.595000      56.000000        6.435000
# 75%     766040.00000        NaN   49.900000      61.250000       13.762500
# max     979607.00000        NaN   59.470000      90.000000       34.520000
#
#                Salary    City
# count      100.000000     100
# ...

# %%
df.describe(percentiles=[.25, .5, .75])  # defaults values
# Out:
#              Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count     100.00000  100.000000     100.000000      100.000000     100.000000
# mean   547652.10000   39.238700      58.080000        8.978400  119738.090000
# std    257664.16679   12.066252      12.294106        8.657358   46185.278194
# min    134841.00000   21.100000      40.000000        0.020000   42005.000000
# 25%    328643.75000   28.177500      50.000000        2.152500   83979.750000
# 50%    497414.00000   37.595000      56.000000        6.435000  118049.500000
# 75%    766040.00000   49.900000      61.250000       13.762500  162509.250000
# max    979607.00000   59.470000      90.000000       34.520000  197537.000000

# %%
df.describe(percentiles=[.25, .4, .5, .6, .75])  # defaults values
# Out:
#              Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count     100.00000  100.000000     100.000000      100.000000     100.000000
# mean   547652.10000   39.238700      58.080000        8.978400  119738.090000
# std    257664.16679   12.066252      12.294106        8.657358   46185.278194
# min    134841.00000   21.100000      40.000000        0.020000   42005.000000
# 25%    328643.75000   28.177500      50.000000        2.152500   83979.750000
# 40%    453173.40000   34.406000      55.000000        3.822000  105240.800000
# 50%    497414.00000   37.595000      56.000000        6.435000  118049.500000
# 60%    622062.20000   42.282000      59.000000        8.532000  131341.200000
# 75%    766040.00000   49.900000      61.250000       13.762500  162509.250000
# max    979607.00000   59.470000      90.000000       34.520000  197537.000000

# %%
df['Emp ID'].std()
# Out:
# 257664.16679011937

# %%
df['Emp ID'].var()
# Out:
# 66390822847.64646

# %%
df['Emp ID'].quantile(0.50)
# Out:
# 497414.0

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isna().mean() *100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Gender          0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# # 1. unique()

# %%
df["Age"].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # 2. nunique()

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Embarked'].nunique()
# Out:
# 3

# %%
df['Survived'].nunique()
# Out:
# 2

# %%
df['Age'].nunique()
# Out:
# 88

# %% [markdown]
# # 3. value_count()

# %%
df['Gender'].value_counts()
# Out:
# male      577
# female    314
# Name: Gender, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    547
# 1    344
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %% [markdown]
# # 4. pd.crosstab()

# %%
use to perform simple cross tabulation of two or more columns

# %%
df['Survived'].value_counts()
# Out:
# 0    547
# 1    344
# Name: Survived, dtype: int64

# %%
pd.crosstab(df['Survived'], df['Gender'])
# Out:
# Gender    female  male
# Survived
# 0             81   466
# 1            233   111

# %%
pd.crosstab(df['Survived'], df['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  370
# 1         136  87  121

# %%
import seaborn as sns

# %%
sns.countplot(x = df['Survived'])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = df['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = df['Survived'], hue=df['Gender'] )
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = df['Survived'], hue=df['Pclass'] )
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts().to_dict()
# Out:
# {0: 547, 1: 344}

# %%
df['Gender'].value_counts().to_dict()
# Out:
# {'male': 577, 'female': 314}

# %% [markdown]
# # 5. Replace

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.replace({'male':1, 'female':0}, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0      1
# 2                               Heikkinen, Miss. Laina       0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       0  35.0      1
# 4                             Allen, Mr. William Henry       1  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
df['Embarked'].replace({np.nan:100}, inplace=True)  # fillna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
df['Embarked'].replace({'S':0, "C":1, "Q":2}, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0      1
# 2                               Heikkinen, Miss. Laina       0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       0  35.0      1
# 4                             Allen, Mr. William Henry       1  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.7+ KB

# %%
# df['Age'].replace({np.nan:1000}, inplace= True)
df['Age'].fillna(1000, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.7+ KB

# %%
df['Age'].value_counts()
# Out:
# 1000.00    177
# 24.00       30
# 22.00       27
# 18.00       26
# 28.00       25
#           ...
# 36.50        1
# 55.50        1
# 0.92         1
# 23.50        1
# 74.00        1
# Name: Age, Length: 89, dtype: int64

# %% [markdown]
# # 7. astype

# %%
df['Age'] = df['Age'].astype(int)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       1    22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0    38      1
# 2                               Heikkinen, Miss. Laina       0    26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       0    35      1
# 4                             Allen, Mr. William Henry       1    35      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Pclass'] = df['Pclass'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    float64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    int64
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    int64
# dtypes: float64(2), int32(1), int64(6), object(3)
# memory usage: 80.2+ KB

# %%
df = pd.DataFrame({"A":np.random.randint(10,20, size=5),
                  "B": [10,20,30,40,50]})
df
# Out:
#     A   B
# 0  15  10
# 1  19  20
# 2  18  30
# 3  12  40
# 4  12  50

# %%
df['C'] = 'Python Data Science'
df
# Out:
#     A   B                    C
# 0  15  10  Python Data Science
# 1  19  20  Python Data Science
# 2  18  30  Python Data Science
# 3  12  40  Python Data Science
# 4  12  50  Python Data Science

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int32
#  1   B       5 non-null      int64
#  2   C       5 non-null      object
# dtypes: int32(1), int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
df['C'] = 100
df
# Out:
#     A   B    C
# 0  15  10  100
# 1  19  20  100
# 2  18  30  100
# 3  12  40  100
# 4  12  50  100

# %%
df['C'] = df['A'] + df['B']
df
# Out:
#     A   B   C
# 0  15  10  25
# 1  19  20  39
# 2  18  30  48
# 3  12  40  52
# 4  12  50  62

# %%
df['D'] = df['A'] ** 2
df
# Out:
#     A   B   C    D
# 0  15  10  25  225
# 1  19  20  39  361
# 2  18  30  48  324
# 3  12  40  52  144
# 4  12  50  62  144

# %%
df['E'] = df['A'] * df['C']
df
# Out:
#     A   B   C    D    E
# 0  15  10  25  225  375
# 1  19  20  39  361  741
# 2  18  30  48  324  864
# 3  12  40  52  144  624
# 4  12  50  62  144  744

# %%
df['E'] = df['D'] + 100
df
# Out:
#     A   B   C    D    E
# 0  15  10  25  225  325
# 1  19  20  39  361  461
# 2  18  30  48  324  424
# 3  12  40  52  144  244
# 4  12  50  62  144  244
